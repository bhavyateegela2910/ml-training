# %%
import pandas as pd

# %%
b = {
    "studentName": ["raj", "ravi", "sita"],
    "studentCourse": ["AI", "ML", "python"],
    "studentId": [101, 102, 103]
}

b1 = pd.DataFrame(b)
print(b1)
# Out:
#   studentName studentCourse  studentId
# 0         raj            AI        101
# 1        ravi            ML        102
# 2        sita        python        103

# %%
b = {
    "studentName": ["raj", "ravi", "sita"],
    "studentCourse": ["AI", "ML", "python"],
    "studentId": [101, 102, 103]
}

b1 = pd.DataFrame(b, index=["a", "b", "c"])
print(b1)
# Out:
#   studentName studentCourse  studentId
# a         raj            AI        101
# b        ravi            ML        102
# c        sita        python        103

# %%
b1 = pd.DataFrame(b, index=["a", "b", "c"])     
print(b1)
# Out:
#   studentName studentCourse  studentId
# a         raj            AI        101
# b        ravi            ML        102
# c        sita        python        103

# %%
#mean:the average of the values in a column
#median:the middle value of the sorted values in a column
#mode:the most frequently occurring value in a column

# %%
import pandas as pd

# Load the dataset (update file path if needed)
df = pd.read_csv("titanic3.csv")

# Display first few rows (optional)
print(df.head())

# Calculate mean of all numeric columns
mean_values = df.mean(numeric_only=True)

print("Mean values of dataset:")
print(mean_values)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 x=titanic3['age'].mean()
#       2 titanic3['age'].fillna(x, inplace=True)
#       3 print(x)
#
# NameError: name 'titanic3' is not defined
