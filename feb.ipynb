# %%
a=10
b="ten"
print(a+b)#type error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 a=10
#       2 b="ten"
# ----> 3 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
    print(10+"ten")
except TypeError:
    print("You are trying to add int and string")
finally:
    print("hello")
# Out:
# You are trying to add int and string
# hello

# %%
if 10>0:#valueerror
    raise ValueError("value cannot be greater than the zero")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 if 10>0:
# ----> 2     raise ValueError("value cannot be greater than the zero")
#
# ValueError: value cannot be greater than the zero
